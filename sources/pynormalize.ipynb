# %%
import os
import pandas as pd
import numpy as np
import librosa
import glob 
import matplotlib.pyplot as plt
import seaborn as sns
import re

import librosa                     # for working with audio in python
import librosa.display             # for waveplots, spectograms, etc
import soundfile as sf             # for accessing file information
from IPython.display import Audio
import soundfile as sf
from pathlib import Path
import warnings
import shutil
import tensorflow as tf

import tqdm
from tqdm import tqdm
from pydub import AudioSegment
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

sns.set()
# tqdm().pandas()
warnings.filterwarnings('ignore')

# Constantes
SAMPLE_RATE = 16000        #  couvre la fréquence de la voix humaine
DT = 0.02

params = {
    'max_audio_length': 5,                                             # T_MAX : Durée max d'un fichie audio
    'alphabet': ' !"&\',-.01234:;\\abcdefghijklmnopqrstuvwxyz',
    'causal_convolutions': False,
    'stack_dilation_rates': [1, 3, 9, 27],
    'stacks': 6,
    'stack_kernel_size': 7,
    'stack_filters': 3*128,
    'sampling_rate': SAMPLE_RATE,
    #
    'n_fft': 160*8,
    'frame_step': 160*4,
    'lower_edge_hertz': 0,
    'upper_edge_hertz': 8000,
    'num_mel_bins': 160
}



DATASET_MAX_ROW = 16460     # all value = #df.shape # (16467, 10)
DATASET_MAX_TRAIN = 13168   # 80%
DATASET_MAX_TEST = 3292     # 20%


#DATASET_MAX_ROW = 1000     # all value = #df.shape # (16467, 10)
#DATASET_MAX_TRAIN = 800    # 80%
#DATASET_MAX_TEST =  200    # 20%

# %%
df = pd.read_csv('datasets/cv-sw-valid.tsv', sep="\t")
df.dataframeName = 'datasets/cv-sw-valid.tsv'
df = df.head(DATASET_MAX_ROW)
df
# Out:
#                                                client_id  \
# 0      05a87054181791477a299a08fc35a6ff0c53250cae313e...
# 1      06c9c9e703dfa759edf4836936b42a07afd1021cedb06c...
# 2      07a7db773acd156dd0b7fdc32f6b5eda9b32ffa1b3aee7...
# 3      0dde0df66454b490f5b9514acb4bb48dc91bbe740254b0...
# 4      0eb85c7dcb9b7ca2caec05a0dbbf6ee983cfab19164dac...
# ...                                                  ...
# 16455  ffd847388e93bcd91855b2a4de02c87c29ed9df053da9c...
# 16456  ffd847388e93bcd91855b2a4de02c87c29ed9df053da9c...
# 16457  ffd847388e93bcd91855b2a4de02c87c29ed9df053da9c...
# 16458  ffd847388e93bcd91855b2a4de02c87c29ed9df053da9c...
# 16459  ffd847388e93bcd91855b2a4de02c87c29ed9df053da9c...
#
#                                path sentence  up_votes  down_votes       age  \
# 0      common_voice_fr_22108074.mp3     zéro         2           0       NaN
# 1      common_voice_fr_22098482.mp3    trois         2           0       NaN
# 2      common_voice_fr_21955578.mp3   quatre         6           3       NaN
# 3      common_voice_fr_22379668.mp3     neuf         2           0  fourties
# 4      common_voice_fr_22157149.mp3  Firefox         3           1       NaN
# ...                             ...      ...       ...         ...       ...
# 16455  common_voice_fr_21954594.mp3      six         2           0       NaN
# 16456  common_voice_fr_21954595.mp3     cinq         3           0       NaN
# 16457  common_voice_fr_21954597.mp3     neuf         3           0       NaN
# 16458  common_voice_fr_21954610.mp3  Firefox         3           1       NaN
# 16459  common_voice_fr_21954612.mp3      oui         2           0       NaN
#
#       gender  accent locale               segment
# 0        NaN     NaN     fr  Singleword Benchmark
# 1        NaN     NaN     fr  Singleword Benchmark
# 2        NaN     NaN     fr  Singleword Benchmark
# 3       male  france     fr  Singleword Benchmark
# 4        NaN     NaN     fr  Singleword Benchmark
# ...      ...     ...    ...                   ...
# 16455    NaN     NaN     fr  Singleword Benchmark
# 16456    NaN     NaN     fr  Singleword Benchmark
# 16457    NaN     NaN     fr  Singleword Benchmark
# 16458    NaN     NaN     fr  Singleword Benchmark
# 16459    NaN     NaN     fr  Singleword Benchmark
#
# [16460 rows x 10 columns]

# %%
from pynormalize.pynormalize import process_files

target_dbfs = -13.5
EDITED_STORE = 'datasets/cv-sw-normalized'

with warnings.catch_warnings():
    # Silence RuntimeWarning about absence of ffmpeg
    warnings.simplefilter("ignore")

def NormalizeAudioFiles(size_ = None):
    Files = []
    all_path_normalized = []
    target_dbfs = -13.5
    df = pd.read_csv('datasets/cv-sw-valid.tsv', sep="\t")
    df.dataframeName = 'datasets/cv-sw-valid.tsv'
    if size_ == None:
        size_ = len(df)
    with tqdm(total=size_) as pbar:
        for index in (range(size_)):
            pbar.update(1)
            audio = df['path'].iloc[index]  
            audio_path = "datasets/cv-sw/" + audio
            fname = Path(audio_path)
            if fname.exists() == True :
                Files = [audio_path]
                process_files(Files=Files, target_dbfs=target_dbfs, directory=EDITED_STORE)
                all_path_normalized.append(audio_path)
            else:
                print("Err fichier non présent: ", audio_path)

        return all_path_normalized      

all_path_normalized = NormalizeAudioFiles()
# Out:
#   0%|          | 0/16467 [00:00<?, ?it/s](1 of 1) Processing file : "common_voice_fr_22108074.mp3"
#   0%|          | 2/16467 [00:00<16:53, 16.24it/s](1 of 1) Processing file : "common_voice_fr_22098482.mp3"
#   0%|          | 3/16467 [00:00<20:07, 13.64it/s](1 of 1) Processing file : "common_voice_fr_21955578.mp3"
# (1 of 1) Processing file : "common_voice_fr_22379668.mp3"
#   0%|          | 5/16467 [00:00<21:41, 12.65it/s](1 of 1) Processing file : "common_voice_fr_22157149.mp3"
#   0%|          | 6/16467 [00:00<26:46, 10.25it/s](1 of 1) Processing file : "common_voice_fr_21967748.mp3"
# (1 of 1) Processing file : "common_voice_fr_22219035.mp3"
#   0%|          | 8/16467 [00:00<27:04, 10.13it/s](1 of 1) Processing file : "common_voice_fr_22064544.mp3"
# (1 of 1) Processing file : "common_voice_fr_22042510.mp3"
#   0%|          | 10/16467 [00:00<26:13, 10.46it/s](1 of 1) Processing file : "common_voice_fr_22386260.mp3"
# (1 of 1) Processing file : "common_voice_fr_22140697.mp3"
#   0%|          | 12/16467 [00:01<26:49, 10.22it/s](1 of 1) Processing file : "common_voice_fr_22298216.mp3"
# (1 of 1) Processing file : "common_voice_fr_22096905.mp3"
#   0%|          | 14/16467 [00:01<27:30,  9.97it/s](1 of 1) Processing file : "common_voice_fr_22120465.mp3"
# (1 of 1) Processing file : "common_voice_fr_22386108.mp3"
#   0%|          | 16/16467 [00:01<26:57, 10.17it/s](1 of 1) Processing file : "common_voice_fr_22376755.mp3"
# (1 of 1) Processing file : "common_voice_fr_22337909.mp3"
#   0%|          | 18/16467 [00:01<27:14, 10.07it/s](1 of 1) Processing file : "common_voice_fr_22159222.mp3"
# (1 of 1) Processing file : "common_voice_fr_22073305.mp3"
#   0%|          | 20/16467 [00:01<26:38, 10.29it/s](1 of 1) Processing file : "common_voice_fr_22166129.mp3"
# (1 of 1) Processing file : "common_voice_fr_22026942.mp3"
#   0%|          | 22/16467 [00:02<26:16, 10.43it/s](1 of 1) Processing file : "common_voice_fr_22372262.mp3"
# (1 of 1) Processing file : "common_voice_fr_21964070.mp3"
#   0%|          | 24/16467 [00:02<26:43, 10.25it/s](1 of 1) Processing file : "common_voice_fr_22168813.mp3"
# (1 of 1) Processing file : "common_voice_fr_22081408.mp3"
#   0%|          | 26/16467 [00:02<27:02, 10.13it/s](1 of 1) Processing file : "common_voice_fr_22025418.mp3"
# (1 of 1) Processing file : "common_voice_fr_22234014.mp3"
#   0%|          | 28/16467 [00:02<26:04, 10.51it/s](1 of 1) Processing file : "common_voice_fr_22385646.mp3"
# (1 of 1) Processing file : "common_voice_fr_21958367.mp3"
#   0%|          | 30/16467 [00:02<26:09, 10.47it/s](1 of 1) Processing file : "common_voice_fr_21953159.mp3"
# (1 of 1) Processing file : "common_voice_fr_22018601.mp3"
#   0%|          | 32/16467 [00:03<26:14, 10.44it/s](1 of 1) Processing file : "common_voice_fr_22385309.mp3"
# (1 of 1) Processing file : "common_voice_fr_22116466.mp3"
#   0%|          | 34/16467 [00:03<25:46, 10.62it/s](1 of 1) Processing file : "common_voice_fr_22378201.mp3"
# (1 of 1) Processing file : "common_voice_fr_22219234.mp3"
#   0%|          | 36/16467 [00:03<25:33, 10.72it/s](1 of 1) Processing file : "common_voice_fr_21987210.mp3"
# (1 of 1) Processing file : "common_voice_fr_21971306.mp3"
#   0%|          | 38/16467 [00:03<25:52, 10.58it/s](1 of 1) Processing file : "common_voice_fr_22087727.mp3"
# (1 of 1) Processing file : "common_voice_fr_21952274.mp3"
#   0%|          | 40/16467 [00:03<25:45, 10.63it/s](1 of 1) Processing file : "common_voice_fr_22122669.mp3"
# (1 of 1) Processing file : "common_voice_fr_22228439.mp3"
#   0%|          | 42/16467 [00:03<25:26, 10.76it/s](1 of 1) Processing file : "common_voice_fr_22070520.mp3"
# (1 of 1) Processing file : "common_voice_fr_22135773.mp3"
#   0%|          | 44/16467 [00:04<27:47,  9.85it/s](1 of 1) Processing file : "common_voice_fr_22223002.mp3"
# (1 of 1) Processing file : "common_voice_fr_21987320.mp3"
#   0%|          | 46/16467 [00:04<27:05, 10.10it/s](1 of 1) Processing file : "common_voice_fr_21907028.mp3"
# (1 of 1) Processing file : "common_voice_fr_21982489.mp3"
#   0%|          | 48/16467 [00:04<28:24,  9.63it/s](1 of 1) Processing file : "common_voice_fr_22114340.mp3"
#   0%|          | 49/16467 [00:04<28:42,  9.53it/s](1 of 1) Processing file : "common_voice_fr_22116532.mp3"
#   0%|          | 50/16467 [00:04<28:21,  9.65it/s](1 of 1) Processing file : "common_voice_fr_22076424.mp3"
#   0%|          | 51/16467 [00:04<28:35,  9.57it/s](1 of 1) Processing file : "common_voice_fr_22222216.mp3"
# (1 of 1) Processing file : "common_voice_fr_22154470.mp3"
#   0%|          | 53/16467 [00:05<28:36,  9.56it/s](1 of 1) Processing file : "common_voice_fr_22120563.mp3"
#   0%|          | 54/16467 [00:05<28:15,  9.68it/s](1 of 1) Processing file : "common_voice_fr_22194006.mp3"
#   0%|          | 55/16467 [00:05<29:31,  9.27it/s](1 of 1) Processing file : "common_voice_fr_22369727.mp3"
# (1 of 1) Processing file : "common_voice_fr_22093383.mp3"
#   0%|          | 57/16467 [00:05<27:53,  9.81it/s](1 of 1) Processing file : "common_voice_fr_22122414.mp3"
# (1 of 1) Processing file : "common_voice_fr_22064340.mp3"
#   0%|          | 59/16467 [00:05<27:24,  9.98it/s](1 of 1) Processing file : "common_voice_fr_21959103.mp3"
# (1 of 1) Processing file : "common_voice_fr_22200493.mp3"
#   0%|          | 61/16467 [00:05<26:51, 10.18it/s](1 of 1) Processing file : "common_voice_fr_22222319.mp3"
# (1 of 1) Processing file : "common_voice_fr_22383843.mp3"
#   0%|          | 63/16467 [00:06<27:07, 10.08it/s](1 of 1) Processing file : "common_voice_fr_22112376.mp3"
# (1 of 1) Processing file : "common_voice_fr_22154857.mp3"
#   0%|          | 65/16467 [00:06<27:24,  9.97it/s](1 of 1) Processing file : "common_voice_fr_22203848.mp3"
# (1 of 1) Processing file : "common_voice_fr_22387536.mp3"
#   0%|          | 67/16467 [00:06<26:53, 10.17it/s](1 of 1) Processing file : "common_voice_fr_22217643.mp3"
# (1 of 1) Processing file : "common_voice_fr_22322116.mp3"
#   0%|          | 69/16467 [00:06<26:53, 10.16it/s](1 of 1) Processing file : "common_voice_fr_21950976.mp3"
# (1 of 1) Processing file : "common_voice_fr_22381166.mp3"
#   0%|          | 71/16467 [00:06<28:11,  9.69it/s](1 of 1) Processing file : "common_voice_fr_22022372.mp3"
#   0%|          | 72/16467 [00:07<28:15,  9.67it/s](1 of 1) Processing file : "common_voice_fr_22384726.mp3"
# (1 of 1) Processing file : "common_voice_fr_22068890.mp3"
#   0%|          | 74/16467 [00:07<27:41,  9.87it/s](1 of 1) Processing file : "common_voice_fr_22381458.mp3"
# (1 of 1) Processing file : "common_voice_fr_22381151.mp3"
#   0%|          | 76/16467 [00:07<27:16, 10.02it/s](1 of 1) Processing file : "common_voice_fr_22390739.mp3"
# (1 of 1) Processing file : "common_voice_fr_22015935.mp3"
#   0%|          | 77/16467 [00:07<27:09, 10.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-cc819e75c9aa> in <module>
#      31         return all_path_normalized
#      32
# ---> 33 all_path_normalized = NormalizeAudioFiles()
#
# <ipython-input-14-cc819e75c9aa> in NormalizeAudioFiles(size_)
#      24             if fname.exists() == True :
#      25                 Files = [audio_path]
# ---> 26                 process_files(Files=Files, target_dbfs=target_dbfs, directory=EDITED_STORE)
#      27                 all_path_normalized.append(audio_path)
#      28             else:
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pynormalize/pynormalize.py in process_files(Files, target_dbfs, directory)
#     115         normalized_sound = song.apply_gain(change_in_dBFS)
#     116         bitrate = '320k' if 'mp3' in extension else None
# --> 117         normalized_sound.export(dest_file, format=extension[1:], bitrate=bitrate)
#     118         # Copy metadata to new file (if the original has metadata)
#     119         if tags:
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pydub/audio_segment.py in export(self, out_f, format, codec, bitrate, parameters, tags, id3v2_version, cover)
#     903         with open(os.devnull, 'rb') as devnull:
#     904             p = subprocess.Popen(conversion_command, stdin=devnull, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
# --> 905         p_out, p_err = p.communicate()
#     906
#     907         log_subprocess_output(p_out)
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     962
#     963             try:
# --> 964                 stdout, stderr = self._communicate(input, endtime, timeout)
#     965             except KeyboardInterrupt:
#     966                 # https://bugs.python.org/issue25942
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1713                             'failed to raise TimeoutExpired.')
#    1714
# -> 1715                     ready = selector.select(timeout)
#    1716                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1717
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
